# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))
# Out:
# {'_request_id': 'req_3fc5eaaf163f44bba92217189ddfd31e',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを効果的に使うためのポイントはいくつかあります。以下にいくつかの重要な点を挙げます。\n\n1. **明確な目的設定**: 使用する目的を明確にすることが重要です。情報検索、文章生成、対話システムなど、目的によってアプローチが変わります。\n\n2. **コンテキストの提供**: モデルに質問やプロンプトを与える際、必要なコンテキストを含めることで、より適切な応答が得られます。\n\n3. **短く具体的な指示**: アンプションやリクエストは具体的かつ短くすることで、モデルが適切に理解しやすくなります。\n\n4. **フィードバックの活用**: モデルから得られた回答に対してフィードバックを行うことで、次回の応答の質を向上させる方法を考えることができます。\n\n5. **結果の評価と調整**: モデルが生成する結果を評価し、必要に応じてプロンプトを調整することで、より満足のいく結果を得ることができます。\n\n6. **倫理的配慮**: 言語モデルを使用する際には、情報の正確性や偏見、プライバシーの問題に注意し、倫理的に使用することが求められます。\n\n7. **限界の理解**: 言語モデルには限界があります。正確性や信頼性に疑問を持つ場合は、他の情報源と照らし合わせることが重要です。\n\n8. **継続的な学習**: 言語モデルやその使用方法は日々進化していますので、最新の情報やベストプラクティスを学び続けることが重要です。\n\nこれらのポイントを考慮に入れることで、言語モデルをより効果的に活用することができるでしょう。', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))],
#  'created': 1770966374,
#  'id': 'chatcmpl-D8hXipq0AJWQSffG9EvI1TCbA3frl',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_f4ae844694',
#  'usage': CompletionUsage(completion_tokens=455, prompt_tokens=18, total_tokens=473, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}

# %%
# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 言語モデルを効果的に使うためのポイントはいくつかあります。以下にいくつかの重要な点を挙げます。
#
# 1. **明確な目的設定**: 使用する目的を明確にすることが重要です。情報検索、文章生成、対話システムなど、目的によってアプローチが変わります。
#
# 2. **コンテキストの提供**: モデルに質問やプロンプトを与える際、必要なコンテキストを含めることで、より適切な応答が得られます。
#
# 3. **短く具体的な指示**: アンプションやリクエストは具体的かつ短くすることで、モデルが適切に理解しやすくなります。
#
# 4. **フィードバックの活用**: モデルから得られた回答に対してフィードバックを行うことで、次回の応答の質を向上させる方法を考えることができます。
#
# 5. **結果の評価と調整**: モデルが生成する結果を評価し、必要に応じてプロンプトを調整することで、より満足のいく結果を得ることができます。
#
# 6. **倫理的配慮**: 言語モデルを使用する際には、情報の正確性や偏見、プライバシーの問題に注意し、倫理的に使用することが求められます。
#
# 7. **限界の理解**: 言語モデルには限界があります。正確性や信頼性に疑問を持つ場合は、他の情報源と照らし合わせることが重要です。
#
# 8. **継続的な学習**: 言語モデルやその使用方法は日々進化していますので、最新の情報やベストプラクティスを学び続けることが重要です。
#
# これらのポイントを考慮に入れることで、言語モデルをより効果的に活用することができるでしょう。

# %%
# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ],
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 新製品の発売に向けた効果的なマーケティング戦略を考える際には、以下のステップやアイディアを考慮することが重要です。
#
# ### 1. **ターゲット市場の特定**
#    - **市場調査**: ターゲット顧客が誰で、どのようなニーズを持っているのかを把握します。ペルソナを設定し、代表的な顧客像を明確にします。
#    - **競合分析**: 競合他社の製品やマーケティング戦略を調査し、自社の強みを把握します。
#
# ### 2. **製品の差別化ポイントの明確化**
#    - **ユニークセリングプロポジション (USP)**: 新製品が持つ独自の特徴や利点を洗い出し、それを前面に出す戦略を考えます。
#
# ### 3. **マーケティングミックスの設計 (4P)**
#    - **製品 (Product)**: 製品の特性やデザイン、パッケージを考慮します。
#    - **価格 (Price)**: 競合や市場価値に基づいた価格設定を行います。初期のプロモーション価格を設定することも有効です。
#    - **場所 (Place)**: 販売チャネルを決定します。オンライン、オフライン、直販、代理店などを考えます。
#    - **プロモーション (Promotion)**: 発売の周知を図る方法を計画します。
#
# ### 4. **ローンチ計画の策定**
#    - **ティーザーキャンペーン**: 発売前に関心を引くためのティーザー広告やコンテンツを展開します。
#    - **プレスリリース**: メディアや業界関係者向けにプレスリリースを配信します。
#    - **インフルエンサーとの連携**: ブランドに合ったインフルエンサーと提携し、レビューやプロモーションを行います。
#
# ### 5. **デジタルマーケティングの活用**
#    - **SNSマーケティング**: Facebook、Instagram、Twitterなどのプラットフォームでの宣伝を行います。
#    - **コンテンツマーケティング**: ブログやビデオを通じて製品の使い方や効果を紹介します。
#    - **SEO対策**: 自社サイトのSEOを強化し、新製品に関する検索流入を増やします。
#
# ### 6. **フィードバックの収集と改善**
#    - **アンケートやレビュー**: 顧客からのフィードバックを収集し、製品やサービスの改善に役立てます。
#    - **販売データの分析**: 販売データを分析し、マーケティング施策の効果を測定し、次の施策に生かします。
#
# ### 7. **アフターサービスと顧客維持戦略**
#    - **フォローアップ**: 発売後も顧客とのコミュニケーションを取り、ロイヤリティを向上させる戦略を考えます。
#    - **リピーターキャンペーン**: 購入後のお礼や次回購入の割引などのキャンペーンを実施します。
#
# これらの戦略を組み合わせて、効果的なマーケティング活動を展開することで、新製品の発売を成功に導くことができるでしょう。

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=1.4,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本は自然、美しい文化、歴史的な名所など、さまざまな魅力を持っています。以下にいくつかのポイントを挙げて紹介します。
#
# ### 1. 美しい自然
# 日本は四季がはっきりしており、各季節ごとに異なる風景を楽しめます。桜の花が咲く春、青々とした山や豊かな海
# --------------------
# 日本の魅力は多岐にわたりますが、いくつかのポイントを挙げてみましょう。
#
# ### 1. 文化と伝統
# 日本は古代からの歴史を持ち、その伝統文化は今も多くの人々に継承されています。神社やお寺、お茶のお点前、そして和歌や伝説伝承など、文化的な遺産が豊かです。
# --------------------
# もちろんです！日本には多くの魅力がありますので、いくつかのポイントを挙げてみますね。
#
# 1. **四季折々の美しさ**: 日本は四季がはっきりしており、春の桜、夏の海、秋の紅葉、冬の雪景色など、すべてが魅力的です。それぞれの季節に応じた楽しみ方があり、自然

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    presence_penalty=-2.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本は、その独自の文化、歴史、自然、そして食文化など、さまざまな魅力を持っています。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **祭り**: 日本各地で開催される祭りは、伝統的な衣装や踊り、音楽で賑わいます。例えば、京都の祇園祭や青
# --------------------
# もちろんです！日本には多くの魅力がありますので、いくつかのポイントを紹介します。
#
# ### 1. 文化と歴史
# 日本は古い歴史と独自の文化を持つ国です。神社や寺、伝統的な祭り、和服、茶道など、古くから受け継がれてきた文化が現在も生きています。例えば、京都の金閣寺や奈良の
# --------------------
# もちろんです！日本には多くの魅力がありますので、いくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# 日本の文化は、何世紀にもわたって蓄積された伝統を持っています。茶道、書道、華道など、様々な伝統芸能や美術があります。また、祭りや伝統的な行事も多く、地域ごとに特色があります。
#
# ###

# %%
import tiktoken
from tiktoken.core import Encoding

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")
# Out:
# tokens_count=2
# tokens=[95839, 3393]

# %%
# トークンの選択度合い
message = """
AさんとBさんで会話してください。
A:あ、Bさんだ。
B:
"""

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    max_tokens=100,
    n=3,
    logit_bias = {95839:8, 3393:8}
)

# 結果を表示
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# B:こんにちは！Aさん、最近どうですか？
# --------------------
# B:こんにちは！Aさん、最近どうしていましたか？
# --------------------
# B:こんにちは！Aさん、久しぶりですね！最近どうですか？

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを使用する上でのポイントはいくつかあります。以下に主なポイントを挙げます。
#
# 1. **明確な目標設定**: 何を達成したいのかを明確にします。例えば、文章生成、質問応答、要約など、目的によって使い方が変わります。
#
# 2. **プロンプト設計**: 入力するプロンプト（指示や質問）の設計が重要です。具体的で明確なプロンプトにすることで、より良い出力が得られます。
#
# 3. **コンテキストの利用**: モデルは前後の文脈を考慮します。関連する情報や適切な文脈を提供することで、モデルの応答を改善できます。
#
# 4. **多様な出力の評価**: モデルはランダム性があるため、複数の出力を生成し、その中から最も適したものを選ぶことが重要です。
#
# 5. **限界を理解する**: モデルはトレーニングデータに基づいて出力を生成するため、最新の情報や専門的な知識には限界があります。結果を批判的に評価することが必要です。
#
# 6. **人間の判断**: モデルの出力は参考として利用しつつ、人間の判断や修正を加えることが重要です。特に重要な決定を行う際には慎重に扱うべきです。
#
# 7. **倫理的配慮**: モデルが生成する内容には偏りや不正確な情報が含まれる可能性があります。倫理的な観点からも、その出力を使用する際には注意が必要です。
#
# 8. **継続的な学習**: モデルの使い方や性能を向上させるために、新しい技術やアプローチを学び続けることが重要です。
#
# これらのポイントを意識することで、言語モデルを効果的に活用することができます。
