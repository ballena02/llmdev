# %%
try:
    a = float(input("1つ目の数を入力してください: "))
    b = float(input("2つ目の数を入力してください: "))

    if b == 0:
        print("エラー: 0で割ることはできません")
    else:
        result = a / b
        print(f"計算結果: {result}")

except ValueError:
    print("エラー: 数値を入力してください")
# Out:
# エラー: 数値を入力してください
